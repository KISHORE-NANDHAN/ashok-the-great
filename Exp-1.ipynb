# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/iris.csv')
print(df)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.min()
# Out:
# Id                         1
# SepalLengthCm            4.3
# SepalWidthCm             2.0
# PetalLengthCm            1.0
# PetalWidthCm             0.1
# Species          Iris-setosa
# dtype: object

# %%
df.max()
# Out:
# Id                          150
# SepalLengthCm               7.9
# SepalWidthCm                4.4
# PetalLengthCm               6.9
# PetalWidthCm                2.5
# Species          Iris-virginica
# dtype: object

# %%
df.count()
# Out:
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
df['SepalLengthCm'].mean()
# Out:
# 5.843333333333334

# %%
df['PetalLengthCm'].std()
# Out:
# 1.7644204199522626

# %%
df['PetalWidthCm'].var()
# Out:
# 0.582414317673378

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df['Species'].describe()
# Out:
# count             150
# unique              3
# top       Iris-setosa
# freq               50
# Name: Species, dtype: object

# %%
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
df.to_numpy()
# Out:
# array([[1, 5.1, 3.5, 1.4, 0.2, 'Iris-setosa'],
#        [2, 4.9, 3.0, 1.4, 0.2, 'Iris-setosa'],
#        [3, 4.7, 3.2, 1.3, 0.2, 'Iris-setosa'],
#        [4, 4.6, 3.1, 1.5, 0.2, 'Iris-setosa'],
#        [5, 5.0, 3.6, 1.4, 0.2, 'Iris-setosa'],
#        [6, 5.4, 3.9, 1.7, 0.4, 'Iris-setosa'],
#        [7, 4.6, 3.4, 1.4, 0.3, 'Iris-setosa'],
#        [8, 5.0, 3.4, 1.5, 0.2, 'Iris-setosa'],
#        [9, 4.4, 2.9, 1.4, 0.2, 'Iris-setosa'],
#        [10, 4.9, 3.1, 1.5, 0.1, 'Iris-setosa'],
#        [11, 5.4, 3.7, 1.5, 0.2, 'Iris-setosa'],
#        [12, 4.8, 3.4, 1.6, 0.2, 'Iris-setosa'],
#        [13, 4.8, 3.0, 1.4, 0.1, 'Iris-setosa'],
#        [14, 4.3, 3.0, 1.1, 0.1, 'Iris-setosa'],
#        [15, 5.8, 4.0, 1.2, 0.2, 'Iris-setosa'],
#        [16, 5.7, 4.4, 1.5, 0.4, 'Iris-setosa'],
#        [17, 5.4, 3.9, 1.3, 0.4, 'Iris-setosa'],
#        [18, 5.1, 3.5, 1.4, 0.3, 'Iris-setosa'],
#        [19, 5.7, 3.8, 1.7, 0.3, 'Iris-setosa'],
#        [20, 5.1, 3.8, 1.5, 0.3, 'Iris-setosa'],
# ...

# %%
df.head() # or df.head(number)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
grouped = df.groupby(['Species'])
grouped.sum().plot.pie(y='PetalWidthCm', subplots=True)
# Out:
# array([<Axes: ylabel='PetalWidthCm'>], dtype=object)

# %%
grouped = df.groupby(['Species'])
grouped.sum().plot.pie(y='PetalLengthCm', subplots=True)
# Out:
# array([<Axes: ylabel='PetalLengthCm'>], dtype=object)

# %%
grouped = df.groupby(['Species'])
grouped.sum().plot.pie(y='SepalWidthCm', subplots=True)
# Out:
# array([<Axes: ylabel='SepalWidthCm'>], dtype=object)

# %%
grouped = df.groupby(['Species'])
grouped.sum().plot.pie(y='SepalLengthCm', subplots=True)
# Out:
# array([<Axes: ylabel='SepalLengthCm'>], dtype=object)
